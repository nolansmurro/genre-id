# %%
import librosa
import matplotlib.pyplot as plt

# %%
y, sr = librosa.load('data/audio/02 Scary Monsters and Nice Sprites.m4a')
# Out:
# /var/folders/q7/5h2c80n91kv48jr01119s4t80000gn/T/ipykernel_8659/234719585.py:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load('data/audio/02 Scary Monsters and Nice Sprites.m4a')
# /Users/nolan/anaconda3/lib/python3.11/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)

# %%
beat_times = librosa.frames_to_time(beat_frames, sr=sr)Ya
# Out:
#   Cell In[27], line 1
#     beat_times = librosa.frames_to_time(beat_frames, sr=sr)Ya
#                                                            ^
# SyntaxError: invalid syntax

# %%
tempo
# Out:
# 143.5546875

# %%
plt.figure(figsize=(10,4))
librosa.display.waveshow(y, sr=sr);

# %%
stft = librosa.stft(y)

# %%
spec_db = librosa.amplitude_to_db(abs(stft))

# %%
plt.figure(figsize=(10,4))
librosa.display.specshow(spec_db, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB');
